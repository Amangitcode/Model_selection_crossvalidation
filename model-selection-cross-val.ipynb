# %%
# import required libs and sklearn iris dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
iris = datasets.load_iris()

# %%
# create X and Y data set to train Y = wX + b model 
# w = weights
# b = bias
X=iris.data
Y=iris.target

# %%
# Model selection: KNeighborsClassifier
# import cross validation model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
# run model for range of K values for KNeighborsClassifier and find the best K value for the model
# Cross validation CV = 10 taken
k_value = []
score = []
for k in range(1,35):
    k_value.append(k)
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, Y, cv=10)
    score.append(scores.mean())
k_value[np.argmax(score)], np.max(score), plt.plot(k_value,score)
# Out:
# (13, 0.9800000000000001, [<matplotlib.lines.Line2D at 0x7f5928b22da0>])

# %%
# Model selection:LogisticRegression 
# import cross validation model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
# Run model for different optimizer: ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
# find best score
# Cross validation CV = 10 taken
import warnings
warnings.filterwarnings('ignore')
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
score=[]
for solve in solvers:
    lr = LogisticRegression(solver= solve)
    scores = cross_val_score(lr, X, Y, cv=10)
    score.append(scores.mean())
solvers[np.argmax(score)], np.max(score), plt.plot(solvers,score)
# Out:
# ('saga', 0.9600000000000002, [<matplotlib.lines.Line2D at 0x7f591a1a8400>])
